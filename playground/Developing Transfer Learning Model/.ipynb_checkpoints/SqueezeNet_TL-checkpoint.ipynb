# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch import tensor
import numpy as np
import torchvision
from torchvision import datasets,transforms,models
from torch.utils.data import DataLoader
from torch.autograd import Variable
from torch.optim import Adam, lr_scheduler
import matplotlib.pyplot as plt
import time
import os
import copy
import random
import shutil
import glob
import torchmetrics
import pathlib
from torchmetrics.classification import Accuracy, Precision, Recall, F1Score
from sklearn.model_selection import StratifiedKFold
import subprocess
import h5py

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
def train_model(model, criterion, optimizer, scheduler,  dataloaders, dataset_sizes, num_epochs=25):
    since = time.time()
    torch.cuda.reset_peak_memory_stats(device)
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    # create a list to store the training and validation accuracy values
    train_acc_list = []
    val_acc_list = []

    # create a list to store the training and validation loss values
    train_loss_list = []
    val_loss_list = []

    # initialize metric
    metric = torchmetrics.classification.Accuracy(task="multiclass", num_classes=3)
    predicted_labels = []
    ground_truth_labels = []

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs-1}')
        print('-'*10)

        #Training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            #Iterate over data
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                #forward
                #track history only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    #_,preds = torch.max(outputs,1)
                    #loss = criterion(outputs,labels)
                    #googlenetcprfix
                    if str(type(outputs)) == "<class 'torch.Tensor'>":
                        _,preds = torch.max(outputs,1)
                        loss = criterion(outputs,labels)
                    else :
                        _,preds = torch.max(outputs.logits,1)
                        loss = criterion(outputs.logits,labels)

                    #backward + optimize only in train
                    if phase == 'train':
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()

                #statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            if phase == 'train':
                train_acc_list.append(epoch_acc.item())
                train_loss_list.append(epoch_loss)
            elif phase == 'val':
                val_acc_list.append(epoch_acc.item())
                val_loss_list.append(epoch_loss)

            predicted_labels.append(preds.cpu())
            ground_truth_labels.append(labels.cpu())


            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            #deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()


    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed//60:.0f}m {time_elapsed%60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    #calculate accuracy
    predicted_labels = torch.cat(predicted_labels)
    ground_truth_labels = torch.cat(ground_truth_labels)
    accuracy = Accuracy(task="multiclass", num_classes=3)
    accuracy(predicted_labels, ground_truth_labels)
    print(f'Accuracy: {accuracy.compute():.4f}')

    #calculate precision
    precision = Precision(task="multiclass", average='macro', num_classes=3)
    precision(predicted_labels, ground_truth_labels)
    print(f'Precision: {precision.compute():.4f}')

    #calculate recall
    recall = Recall(task="multiclass", average='macro', num_classes=3)
    recall(predicted_labels, ground_truth_labels)
    print(f'Recall: {recall.compute():.4f}')

    #calculate f1 score
    f1 = F1Score(task="multiclass", average='macro', num_classes=3)
    f1(predicted_labels, ground_truth_labels)
    print(f'F1: {f1.compute():.4f}')

    #calculate confusion matrix
    cm = torchmetrics.functional.confusion_matrix(predicted_labels, ground_truth_labels, num_classes=3, task="multiclass")
    print(f'Confusion Matrix: \n{cm}')

    #plot the training and validation accuracy
    plt.figure(figsize=(10, 6))

    plt.plot(train_acc_list, label='Training Accuracy')
    plt.plot(val_acc_list, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.grid(True)

    plt.show()

    #plot the training and validation loss

    plt.figure(figsize=(10, 6))

    plt.plot(train_loss_list, label='Training Loss')
    plt.plot(val_loss_list, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)

    plt.show()

    metrics = {}
    metrics['accuracy'] = accuracy.compute()
    metrics['precision'] = precision.compute()
    metrics['recall'] = recall.compute()
    metrics['f1'] = f1.compute()
    metrics['time'] = time_elapsed
    metrics['memory'] = torch.cuda.max_memory_allocated()/(1024*1024)


    #load best model weights
    model.load_state_dict(best_model_wts)
    return model, metrics

# %%
def print_metrics(metrics):
  #total_time = metrics["time"]*5
  print(f'Average accuracy: {metrics["accuracy"]:.4f}')
  print(f'Average precision: {metrics["precision"]:.4f}')
  print(f'Average recall: {metrics["recall"]:.4f}')
  print(f'Average F1 score: {metrics["f1"]:.4f}')
  print(f'Average Time elapsed: {metrics["time"]:.4f} seconds')
  print(f'Memory Usage: {metrics["memory"]:.4f} MiB')

# %%
def get_transforms():
    mean = np.array([0.485,0.456,0.406])
    std = np.array([0.229,0.224,0.225])
    data_transforms = {
          'train':transforms.Compose([
              transforms.RandomResizedCrop(224),
              transforms.RandomHorizontalFlip(),
              transforms.ToTensor(),
              transforms.Normalize(mean,std)
          ]),
          'val':transforms.Compose([
              transforms.Resize(256),
              transforms.CenterCrop(224),
              transforms.ToTensor(),
              transforms.Normalize(mean,std)
          ])
      }
    return data_transforms

# %%
with h5py.File(os.path.join('../../datasets', 'ecg_data', 'train_ecg.hdf5'), 'r') as hdf:
    x = hdf['x_train'][:2]
    y = hdf['y_train'][:2]
    print(f'x: {x}\n y: {y}')
# Out:
# x: [[[0.47621218 0.50096342 0.50294299 0.46303273 0.42054075 0.41794807
#    0.4286182  0.4462329  0.46512831 0.47410243 0.47995983 0.4869455
#    0.48992241 0.48249982 0.47189347 0.45860304 0.45215176 0.47244653
#    0.49538254 0.49949936 0.49843796 0.49746782 0.49496506 0.49164869
#    0.48723655 0.47869662 0.47326381 0.48292294 0.49338693 0.49148231
#    0.48655512 0.48339012 0.47962191 0.47454021 0.46900796 0.46349089
#    0.45822001 0.4537282  0.44976588 0.4461381  0.44324834 0.44168869
#    0.44081725 0.44166378 0.44085934 0.43157546 0.42303933 0.42270658
#    0.42794644 0.4434478  0.45932207 0.46661455 0.46780117 0.4576057
#    0.44544252 0.44163622 0.43875378 0.42123444 0.41866177 0.47364785
#    0.53976035 0.58573583 0.61824316 0.61711256 0.6146758  0.6628272
#    0.69504284 0.65627981 0.57122772 0.41926656 0.27023215 0.20549378
#    0.17710238 0.17789824 0.1925988  0.2052016  0.21025276 0.17646282
#    0.1490476  0.1799834  0.22196145 0.24002636 0.25688267 0.28234373
#    0.3120003  0.34833855 0.38483287 0.41993913 0.4443397  0.44057593
#    0.42639412 0.40999319 0.39653728 0.3995044  0.40739348 0.41561947
#    0.42127266 0.4152083  0.40761551 0.40620129 0.40770231 0.41346846
#    0.4202756  0.42854174 0.43098654 0.41355849 0.39272008 0.38022788
#    0.37318123 0.37606167 0.3831334  0.39361006 0.40024528 0.38821753
#    0.37469    0.37587572 0.37920463 0.37795248 0.37448048 0.36594553
#    0.3579552  0.35705076 0.35817665 0.35884219 0.3595111  0.35928306
#    0.35889955 0.35871417 0.35874571 0.35926482]]
#
#  [[0.42854086 0.42768517 0.42642484 0.42496622 0.42329634 0.42150381
#    0.41955434 0.41742039 0.41517461 0.41292363 0.41055937 0.40809309
#    0.40534862 0.40195423 0.39838454 0.39495944 0.39167386 0.38854534
#    0.38584013 0.38362422 0.38238964 0.38300185 0.38464204 0.38691224
#    0.38968067 0.39250289 0.39572181 0.39943069 0.40377664 0.4091783
#    0.41508552 0.42107859 0.42726712 0.43384545 0.44019308 0.44618675
#    0.45084266 0.45233008 0.45253261 0.4525951  0.4524372  0.45221917
#    0.45251563 0.45337625 0.45620511 0.46348168 0.47270747 0.48282445
#    0.49289887 0.50060697 0.50818431 0.51414873 0.52498578 0.55413719
#    0.58363787 0.60688704 0.61039822 0.57129692 0.50522763 0.40418795
#    0.30133553 0.23526141 0.18508853 0.14571368 0.1183512  0.10269299
#    0.09724328 0.10027383 0.11202735 0.1337801  0.16135484 0.19271884
#    0.22406686 0.24872873 0.2714603  0.29392267 0.31677871 0.34338026
#    0.3690168  0.38744929 0.40565154 0.42964088 0.45544473 0.48489472
#    0.51025497 0.52071703 0.52539309 0.52895849 0.53111803 0.53399314
#    0.53653293 0.53817968 0.5398863  0.54272663 0.54585647 0.54892259
#    0.55183549 0.55412193 0.55633796 0.55870447 0.56154247 0.56554887
#    0.57005382 0.57474134 0.57946989 0.583815   0.58813109 0.59249927
#    0.5971427  0.60261568 0.60821478 0.61342726 0.61835558 0.62316154
#    0.62719176 0.63031567 0.63145619 0.62862868 0.62385308 0.6181758
#    0.61191898 0.60608392 0.60010777 0.59386563 0.58732114 0.580036
#    0.57283766 0.5660716  0.56044162 0.55727922]]]
#  y: [2 4]

# %%
def preTrainImageNet(model_name, classes):
  data_transforms = get_transforms()
  # Get a list of all image filenames and corresponding labels
  all_filenames = []
  all_labels = []
  # Iterate through each class folder and associate each image with corresponding lable
  for class_name in classes:
      folder_path = './THB_dataset'
      class_folder = os.path.join(folder_path, class_name)
      class_filenames = [os.path.join(class_folder, filename) for filename in os.listdir(class_folder)]

      # Extend the list of all_filenames and all_labels
      all_filenames.extend(class_filenames)
      all_labels.extend([class_name] * len(class_filenames))

  # Use StratifiedKFold for creating folds
  num_folds = 5
  stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

  all_metrics = []

  # Perform stratified k-fold cross-validation
  for i, (train_idx, test_idx) in enumerate(stratified_kfold.split(all_filenames, all_labels)):
    train_FileNames = [all_filenames[idx] for idx in train_idx]
    val_FileNames = [all_filenames[idx] for idx in test_idx]
    print('Fold: ',i)
    print('Training: ', len(train_FileNames))
    print('Validation: ', len(val_FileNames))
    fold_dir = f'./splitted_dataset/fold{i}'
    # if not os.path.exists(fold_dir):
    os.makedirs(fold_dir+'/train')
    os.makedirs(fold_dir+'/val')

    # Creating the class folders in train and validation folders
    for class_name in classes:
        os.makedirs(fold_dir+'/train/' + class_name)
        os.makedirs(fold_dir+'/val/' + class_name)

    for name in train_FileNames:
        name_split = name.split('\\')
        class_name = name_split[1] + '/' + name_split[2]
        shutil.copy(name, fold_dir+'/train/' + class_name)
    for name in val_FileNames:
        name_split = name.split('\\')
        class_name = name_split[1] + '/' + name_split[2]
        shutil.copy(name, fold_dir+'/val/' + class_name)


    sets = ['train','val']
    image_datasets = {x:datasets.ImageFolder(os.path.join(fold_dir,x),
                                            data_transforms[x])
                    for x in ['train','val']}
    dataloaders = {x:torch.utils.data.DataLoader(image_datasets[x],batch_size=4,
                                                shuffle=True,num_workers=0)
                    for x in ['train','val']}

    dataset_sizes = {x:len(image_datasets[x]) for x in ['train','val']}


    pretrained_model_ImageNet = models.squeezenet1_1(pretrained=True)

    #freezing previous layers
    for param in pretrained_model_ImageNet.features.parameters():
        param.requires_grad = False

    #exchange the last layer
    num_classes = 3

    if model_name in ['googlenet', 'resnet18']:
        pretrained_model_ImageNet.fc = nn.Linear(in_features=pretrained_model_ImageNet.fc.in_features, out_features=num_classes, device=device)
    elif model_name in ['alexnet', 'vgg16']:
        num_ftrs = pretrained_model_ImageNet.classifier[6].in_features
        pretrained_model_ImageNet.classifier[6] = nn.Linear(num_ftrs, num_classes)
    elif model_name == 'squeezenet':
        # Newly created modules have require_grad=True by default
        num_features = pretrained_model_ImageNet.classifier[1].in_channels
        features = list(pretrained_model_ImageNet.classifier.children())[:-3] # Remove last 3 layers
        features.extend([nn.Conv2d(num_features, num_classes, kernel_size=1)]) # Add
        features.extend([nn.ReLU(inplace=True)]) # Add
        features.extend([nn.AdaptiveAvgPool2d(output_size=(1,1))]) # Add
        pretrained_model_ImageNet.classifier = nn.Sequential(*features)

    elif model_name == 'inceptionv3':
        num_ftrs = pretrained_model_ImageNet.fc.in_features
        pretrained_model_ImageNet.fc = nn.Linear(num_ftrs, 3)
    else:
        #use voltavision here.
        raise ValueError(f"Invalid model_name: {model_name}")

    pretrained_model_ImageNet.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(pretrained_model_ImageNet.parameters(),lr=0.001)

    #scheduler
    step_lr_scheduler = lr_scheduler.StepLR(optimizer,step_size=7,gamma=0.1)

    model_ft, metrics = train_model(pretrained_model_ImageNet, criterion, optimizer, step_lr_scheduler, dataloaders, dataset_sizes, num_epochs=25)

    all_metrics.append(metrics)

  avg_metrics = {key: np.mean([m[key] for m in all_metrics]) for key in all_metrics[0]}
  print_metrics(avg_metrics)
  # print_performance()

# %%
folder_path = 'THB_dataset'
classes = os.listdir(folder_path)
print(classes)
# Out:
# ['Bluetooth', 'Humidity', 'Transistor']

# %%
preTrainImageNet("squeezenet",classes)
# Out:
# Fold:  0
# Training:  262
# Validation:  66
# Bluetooth/btm_1.jpg
# Bluetooth/btm_10.jpg
# Bluetooth/btm_105.jpg
# Bluetooth/btm_106.jpg
# Bluetooth/btm_107.jpg
# Bluetooth/btm_108.jpg
# Bluetooth/btm_109.jpg
# Bluetooth/btm_11.jpg
# Bluetooth/btm_127.jpg
# Bluetooth/btm_128.jpg
# Bluetooth/btm_129.jpg
# Bluetooth/btm_13.jpg
# Bluetooth/btm_132.jpg
# Bluetooth/btm_135.jpg
# Bluetooth/btm_14.jpg
# Bluetooth/btm_145.jpg
# val Loss: 0.0619 Acc: 0.9848
#
# Epoch 11/24
# ----------
# train Loss: 0.1044 Acc: 0.9733
# val Loss: 0.0599 Acc: 0.9848
#
# Epoch 12/24
# ----------
# train Loss: 0.1190 Acc: 0.9733
# val Loss: 0.0619 Acc: 0.9848
#
# Epoch 13/24
# ----------
# train Loss: 0.1390 Acc: 0.9504
# val Loss: 0.0630 Acc: 0.9848
#
# Epoch 14/24
# ----------
# train Loss: 0.1480 Acc: 0.9542
# val Loss: 0.0629 Acc: 0.9848
#
# Epoch 15/24
# ----------
# train Loss: 0.1473 Acc: 0.9542
# val Loss: 0.0626 Acc: 0.9848
#
# Epoch 16/24
# ----------
# train Loss: 0.1336 Acc: 0.9580
# val Loss: 0.0625 Acc: 0.9848
#
# Epoch 17/24
# ----------
# train Loss: 0.1214 Acc: 0.9580
# val Loss: 0.0623 Acc: 0.9848
#
# Epoch 18/24
# ----------
# train Loss: 0.1373 Acc: 0.9580
# val Loss: 0.0619 Acc: 0.9848
#
# Epoch 19/24
# ----------
# train Loss: 0.1714 Acc: 0.9122
# val Loss: 0.0623 Acc: 0.9848
#
# Epoch 20/24
# ----------
# train Loss: 0.1341 Acc: 0.9542
# val Loss: 0.0618 Acc: 0.9848
#
# Epoch 21/24
# ----------
# train Loss: 0.1689 Acc: 0.9389
# val Loss: 0.0618 Acc: 0.9848
#
# Epoch 22/24
# ----------
# train Loss: 0.1268 Acc: 0.9695
# val Loss: 0.0618 Acc: 0.9848
#
# Epoch 23/24
# ----------
# train Loss: 0.1107 Acc: 0.9695
# val Loss: 0.0618 Acc: 0.9848
#
# Epoch 24/24
# ----------
# train Loss: 0.1526 Acc: 0.9504
# val Loss: 0.0617 Acc: 0.9848
#
# Training complete in 1m 31s
# Best val Acc: 0.984848
# Accuracy: 0.9500
# Precision: 0.9455
# Recall: 0.9500
# F1: 0.9472
# Confusion Matrix:
# tensor([[28,  2,  0],
#         [ 1, 28,  0],
#         [ 1,  1, 39]])
# Fold:  1
# Training:  262
# Validation:  66
# Bluetooth/btm_10.jpg
# Bluetooth/btm_105.jpg
# Bluetooth/btm_106.jpg
# Bluetooth/btm_107.jpg
# Bluetooth/btm_109.jpg
# Bluetooth/btm_11.jpg
# Bluetooth/btm_110.jpg
# Bluetooth/btm_112.jpg
# Bluetooth/btm_12.jpg
# Bluetooth/btm_128.jpg
# Bluetooth/btm_129.jpg
# Bluetooth/btm_13.jpg
# Bluetooth/btm_131.jpg
# Bluetooth/btm_132.jpg
# Bluetooth/btm_137.jpg
# Bluetooth/btm_145.jpg
# Bluetooth/btm_146.jpg
# Bluetooth/btm_148.jpg
# Bluetooth/btm_149.jpg
# Bluetooth/btm_15.jpg
# Bluetooth/btm_150.jpg
# Bluetooth/btm_151.jpg
# Bluetooth/btm_160.jpg
# Bluetooth/btm_161.jpg
# Bluetooth/btm_162.jpg
# Bluetooth/btm_163.jpg
# Bluetooth/btm_164.jpg
# Bluetooth/btm_166.jpg
# Bluetooth/btm_168.jpg
# train Loss: 0.1418 Acc: 0.9580
# val Loss: 0.0748 Acc: 0.9848
#
# Epoch 16/24
# ----------
# train Loss: 0.0976 Acc: 0.9695
# val Loss: 0.0744 Acc: 0.9848
#
# Epoch 17/24
# ----------
# train Loss: 0.1593 Acc: 0.9466
# val Loss: 0.0740 Acc: 0.9848
#
# Epoch 18/24
# ----------
# train Loss: 0.1322 Acc: 0.9618
# val Loss: 0.0738 Acc: 0.9848
#
# Epoch 19/24
# ----------
# train Loss: 0.1457 Acc: 0.9466
# val Loss: 0.0736 Acc: 0.9848
#
# Epoch 20/24
# ----------
# train Loss: 0.1422 Acc: 0.9466
# val Loss: 0.0734 Acc: 0.9848
#
# Epoch 21/24
# ----------
# train Loss: 0.2040 Acc: 0.9313
# val Loss: 0.0734 Acc: 0.9848
#
# Epoch 22/24
# ----------
# train Loss: 0.1667 Acc: 0.9466
# val Loss: 0.0734 Acc: 0.9848
#
# Epoch 23/24
# ----------
# train Loss: 0.1554 Acc: 0.9542
# val Loss: 0.0734 Acc: 0.9848
#
# Epoch 24/24
# ----------
# train Loss: 0.1336 Acc: 0.9618
# val Loss: 0.0734 Acc: 0.9848
#
# Training complete in 1m 37s
# Best val Acc: 0.984848
# Accuracy: 0.9600
# Precision: 0.9619
# Recall: 0.9603
# F1: 0.9593
# Confusion Matrix:
# tensor([[27,  2,  0],
#         [ 0, 31,  0],
#         [ 0,  2, 38]])
# Fold:  2
# Training:  262
# Validation:  66
# Bluetooth/btm_1.jpg
# Bluetooth/btm_10.jpg
# Bluetooth/btm_105.jpg
# Bluetooth/btm_108.jpg
# Bluetooth/btm_109.jpg
# Bluetooth/btm_110.jpg
# Bluetooth/btm_112.jpg
# Bluetooth/btm_12.jpg
# Bluetooth/btm_127.jpg
# Bluetooth/btm_128.jpg
# Bluetooth/btm_129.jpg
# Bluetooth/btm_13.jpg
# Bluetooth/btm_131.jpg
# Bluetooth/btm_132.jpg
# Bluetooth/btm_135.jpg
# Bluetooth/btm_137.jpg
# Bluetooth/btm_14.jpg
# Bluetooth/btm_145.jpg
# Bluetooth/btm_147.jpg
# Bluetooth/btm_148.jpg
# Bluetooth/btm_15.jpg
# Bluetooth/btm_150.jpg
# Bluetooth/btm_151.jpg
# Bluetooth/btm_159.jpg
# Bluetooth/btm_160.jpg
# Bluetooth/btm_161.jpg
# Bluetooth/btm_162.jpg
# Bluetooth/btm_163.jpg
# Bluetooth/btm_165.jpg
# Bluetooth/btm_166.jpg
# Bluetooth/btm_168.jpg
# Bluetooth/btm_169.jpg
# Bluetooth/btm_173.jpg
# Bluetooth/btm_174.jpg
# Bluetooth/btm_175.jpg
# Bluetooth/btm_176.jpg
# Bluetooth/btm_177.jpg
# Bluetooth/btm_178.jpg
# Bluetooth/btm_18.jpg
# Bluetooth/btm_19.jpg
# Bluetooth/btm_20.jpg
# Bluetooth/btm_21.jpg
# Bluetooth/btm_22.jpg
# Bluetooth/btm_23.jpg
# Bluetooth/btm_26.jpg
# Transistor/trans_77.jpg
# Transistor/trans_78.jpg
# Transistor/trans_79.jpg
# Transistor/trans_8.jpg
# Transistor/trans_81.jpg
# Transistor/trans_82.jpg
# Transistor/trans_83.jpg
# Transistor/trans_84.jpg
# Transistor/trans_85.jpg
# Transistor/trans_86.jpg
# Transistor/trans_87.jpg
# Transistor/trans_88.jpg
# Transistor/trans_89.jpg
# Transistor/trans_90.jpg
# Transistor/trans_92.jpg
# Transistor/trans_94.jpg
# Transistor/trans_96.jpg
# Transistor/trans_97.jpg
# Transistor/trans_98.jpg
# Transistor/trans_99.jpg
# Epoch 0/24
# ----------
# train Loss: 0.6989 Acc: 0.7366
# val Loss: 0.4013 Acc: 0.7727
#
# Epoch 1/24
# ----------
# train Loss: 0.3765 Acc: 0.8740
# val Loss: 0.3869 Acc: 0.8485
#
# Epoch 2/24
# ----------
# train Loss: 0.2846 Acc: 0.9122
# val Loss: 0.2726 Acc: 0.8788
#
# Epoch 3/24
# ----------
# train Loss: 0.2377 Acc: 0.9237
# val Loss: 0.1329 Acc: 0.9545
#
# Epoch 4/24
# ----------
# train Loss: 0.2165 Acc: 0.9351
# val Loss: 0.1288 Acc: 0.9545
#
# Epoch 5/24
# ----------
# train Loss: 0.1839 Acc: 0.9351
# val Loss: 0.1129 Acc: 0.9545
#
# Epoch 6/24
# ----------
# train Loss: 0.1675 Acc: 0.9504
# val Loss: 0.0743 Acc: 0.9848
#
# Epoch 7/24
# ----------
# train Loss: 0.1666 Acc: 0.9504
# val Loss: 0.0733 Acc: 1.0000
#
# Epoch 8/24
# ----------
# train Loss: 0.1297 Acc: 0.9656
# val Loss: 0.0722 Acc: 0.9848
#
# Epoch 9/24
# ----------
# train Loss: 0.1029 Acc: 0.9809
# val Loss: 0.0706 Acc: 0.9848
#
# Epoch 10/24
# ----------
# train Loss: 0.1493 Acc: 0.9504
# val Loss: 0.0689 Acc: 0.9848
#
# Epoch 11/24
# ----------
# train Loss: 0.1174 Acc: 0.9618
# val Loss: 0.0700 Acc: 1.0000
#
# Epoch 12/24
# ----------
# train Loss: 0.1166 Acc: 0.9733
# val Loss: 0.0689 Acc: 1.0000
#
# Epoch 13/24
# ----------
# train Loss: 0.1027 Acc: 0.9809
# val Loss: 0.0676 Acc: 1.0000
#
# Epoch 14/24
# ----------
# train Loss: 0.1511 Acc: 0.9580
# val Loss: 0.0674 Acc: 1.0000
#
# Epoch 15/24
# ----------
# train Loss: 0.0957 Acc: 0.9885
# val Loss: 0.0674 Acc: 1.0000
#
# Epoch 16/24
# ----------
# train Loss: 0.1182 Acc: 0.9733
# val Loss: 0.0674 Acc: 1.0000
#
# Epoch 17/24
# ----------
# train Loss: 0.1528 Acc: 0.9542
# val Loss: 0.0675 Acc: 1.0000
#
# Epoch 18/24
# ----------
# train Loss: 0.1583 Acc: 0.9504
# val Loss: 0.0678 Acc: 1.0000
#
# Epoch 19/24
# ----------
# train Loss: 0.1339 Acc: 0.9580
# val Loss: 0.0679 Acc: 1.0000
#
# Epoch 20/24
# ----------
# train Loss: 0.1253 Acc: 0.9656
# val Loss: 0.0680 Acc: 1.0000
#
# Epoch 21/24
# ----------
# train Loss: 0.1212 Acc: 0.9695
# val Loss: 0.0679 Acc: 1.0000
#
# Epoch 22/24
# ----------
# train Loss: 0.1321 Acc: 0.9504
# val Loss: 0.0679 Acc: 1.0000
#
# Epoch 23/24
# ----------
# train Loss: 0.1142 Acc: 0.9771
# val Loss: 0.0679 Acc: 1.0000
#
# Epoch 24/24
# ----------
# train Loss: 0.0887 Acc: 0.9885
# val Loss: 0.0679 Acc: 1.0000
#
# Training complete in 1m 41s
# Best val Acc: 1.000000
# Accuracy: 0.9400
# Precision: 0.9393
# Recall: 0.9397
# F1: 0.9385
# Confusion Matrix:
# tensor([[31,  3,  1],
#         [ 1, 28,  1],
#         [ 0,  0, 35]])
# Fold:  3
# Training:  263
# Validation:  65
# Bluetooth/btm_1.jpg
# Bluetooth/btm_106.jpg
# Bluetooth/btm_107.jpg
# Bluetooth/btm_108.jpg
# Bluetooth/btm_109.jpg
# Bluetooth/btm_11.jpg
# Bluetooth/btm_110.jpg
# Bluetooth/btm_112.jpg
# Bluetooth/btm_12.jpg
# Bluetooth/btm_127.jpg
# Bluetooth/btm_128.jpg
# Bluetooth/btm_129.jpg
# Bluetooth/btm_131.jpg
# Bluetooth/btm_135.jpg
# Bluetooth/btm_137.jpg
# Bluetooth/btm_14.jpg
# Bluetooth/btm_145.jpg
# Bluetooth/btm_146.jpg
# Bluetooth/btm_147.jpg
# Bluetooth/btm_149.jpg
# Bluetooth/btm_15.jpg
# Bluetooth/btm_150.jpg
# Bluetooth/btm_159.jpg
# Bluetooth/btm_160.jpg
# Bluetooth/btm_161.jpg
# Bluetooth/btm_162.jpg
# Bluetooth/btm_163.jpg
# Bluetooth/btm_164.jpg
# Bluetooth/btm_165.jpg
# Bluetooth/btm_168.jpg
# Bluetooth/btm_174.jpg
# Bluetooth/btm_175.jpg
# Bluetooth/btm_176.jpg
# Bluetooth/btm_177.jpg
# Bluetooth/btm_178.jpg
# Bluetooth/btm_179.jpg
# Bluetooth/btm_19.jpg
# Bluetooth/btm_20.jpg
# Bluetooth/btm_21.jpg
# Bluetooth/btm_22.jpg
# Bluetooth/btm_24.jpg
# Bluetooth/btm_26.jpg
# Bluetooth/btm_27.jpg
# Bluetooth/btm_3.jpg
# Bluetooth/btm_32.jpg
# Bluetooth/btm_33.jpg
# Bluetooth/btm_35.jpg
# Bluetooth/btm_38.jpg
# Bluetooth/btm_4.jpg
# Bluetooth/btm_42.jpg
# Bluetooth/btm_43.jpg
# Bluetooth/btm_45.jpg
# Bluetooth/btm_46.jpg
# Bluetooth/btm_47.jpg
# Bluetooth/btm_49.jpg
# Bluetooth/btm_50.jpg
# Bluetooth/btm_51.jpg
# Bluetooth/btm_54.jpg
# Bluetooth/btm_55.jpg
# Bluetooth/btm_56.jpg
# Bluetooth/btm_57.jpg
# Bluetooth/btm_58.jpg
# Transistor/trans_98.jpg
# Transistor/trans_99.jpg
# Epoch 0/24
# ----------
# train Loss: 0.9056 Acc: 0.5894
# val Loss: 0.3997 Acc: 0.8308
#
# Epoch 1/24
# ----------
# train Loss: 0.4167 Acc: 0.8555
# val Loss: 0.1673 Acc: 1.0000
#
# Epoch 2/24
# ----------
# train Loss: 0.2456 Acc: 0.9354
# val Loss: 0.1194 Acc: 0.9846
#
# Epoch 3/24
# ----------
# train Loss: 0.2263 Acc: 0.9278
# val Loss: 0.0988 Acc: 0.9846
#
# Epoch 4/24
# ----------
# train Loss: 0.1973 Acc: 0.9354
# val Loss: 0.0787 Acc: 0.9846
#
# Epoch 5/24
# ----------
# train Loss: 0.1690 Acc: 0.9506
# val Loss: 0.0709 Acc: 0.9846
#
# Epoch 6/24
# ----------
# train Loss: 0.1340 Acc: 0.9696
# val Loss: 0.0757 Acc: 0.9846
#
# Epoch 7/24
# ----------
# train Loss: 0.1221 Acc: 0.9620
# val Loss: 0.0659 Acc: 0.9846
#
# Epoch 8/24
# ----------
# train Loss: 0.1351 Acc: 0.9658
# val Loss: 0.0604 Acc: 0.9846
#
# Epoch 9/24
# ----------
# train Loss: 0.1985 Acc: 0.9354
# val Loss: 0.0625 Acc: 0.9846
#
# Epoch 10/24
# ----------
# train Loss: 0.1057 Acc: 0.9810
# val Loss: 0.0589 Acc: 0.9846
#
# Epoch 11/24
# ----------
# train Loss: 0.1652 Acc: 0.9430
# val Loss: 0.0574 Acc: 0.9846
#
# Epoch 12/24
# ----------
# train Loss: 0.1164 Acc: 0.9772
# val Loss: 0.0567 Acc: 0.9846
#
# Epoch 13/24
# ----------
# train Loss: 0.1508 Acc: 0.9544
# val Loss: 0.0565 Acc: 0.9846
#
# Epoch 14/24
# ----------
# train Loss: 0.1050 Acc: 0.9810
# val Loss: 0.0565 Acc: 0.9846
#
# Epoch 15/24
# ----------
# train Loss: 0.1326 Acc: 0.9658
# val Loss: 0.0566 Acc: 0.9846
#
# Epoch 16/24
# ----------
# train Loss: 0.1643 Acc: 0.9430
# val Loss: 0.0567 Acc: 0.9846
#
# Epoch 17/24
# ----------
# train Loss: 0.1004 Acc: 0.9734
# val Loss: 0.0566 Acc: 0.9846
#
# Epoch 18/24
# ----------
# train Loss: 0.1218 Acc: 0.9696
# val Loss: 0.0564 Acc: 0.9846
#
# Epoch 19/24
# ----------
# train Loss: 0.1666 Acc: 0.9544
# val Loss: 0.0570 Acc: 0.9846
#
# Epoch 20/24
# ----------
# train Loss: 0.1504 Acc: 0.9544
# val Loss: 0.0569 Acc: 0.9846
#
# Epoch 21/24
# ----------
# train Loss: 0.1437 Acc: 0.9620
# val Loss: 0.0569 Acc: 0.9846
#
# Epoch 22/24
# ----------
# train Loss: 0.1285 Acc: 0.9582
# val Loss: 0.0569 Acc: 0.9846
#
# Epoch 23/24
# ----------
# train Loss: 0.1160 Acc: 0.9696
# val Loss: 0.0569 Acc: 0.9846
#
# Epoch 24/24
# ----------
# val Loss: 0.0631 Acc: 1.0000
#
# Epoch 4/24
# ----------
# train Loss: 0.2210 Acc: 0.9240
# val Loss: 0.0509 Acc: 1.0000
#
# Epoch 5/24
# ----------
# train Loss: 0.2002 Acc: 0.9125
# val Loss: 0.0475 Acc: 1.0000
#
# Epoch 6/24
# ----------
# train Loss: 0.1513 Acc: 0.9430
# val Loss: 0.0377 Acc: 1.0000
#
# Epoch 7/24
# ----------
# train Loss: 0.1426 Acc: 0.9658
# val Loss: 0.0325 Acc: 1.0000
#
# Epoch 8/24
# ----------
# train Loss: 0.1451 Acc: 0.9582
# val Loss: 0.0306 Acc: 1.0000
#
# Epoch 9/24
# ----------
# train Loss: 0.1528 Acc: 0.9430
# val Loss: 0.0301 Acc: 1.0000
#
# Epoch 10/24
# ----------
# train Loss: 0.1597 Acc: 0.9430
# val Loss: 0.0302 Acc: 1.0000
#
# Epoch 11/24
# ----------
# train Loss: 0.1656 Acc: 0.9506
# val Loss: 0.0301 Acc: 1.0000
#
# Epoch 12/24
# ----------
# train Loss: 0.1481 Acc: 0.9430
# val Loss: 0.0304 Acc: 1.0000
#
# Epoch 13/24
# ----------
# train Loss: 0.1384 Acc: 0.9544
# val Loss: 0.0311 Acc: 1.0000
#
# Epoch 14/24
# ----------
# train Loss: 0.1430 Acc: 0.9582
# val Loss: 0.0306 Acc: 1.0000
#
# Epoch 15/24
# ----------
# train Loss: 0.1398 Acc: 0.9620
# val Loss: 0.0304 Acc: 1.0000
#
# Epoch 16/24
# ----------
# train Loss: 0.1228 Acc: 0.9620
# val Loss: 0.0301 Acc: 1.0000
#
# Epoch 17/24
# ----------
# train Loss: 0.1032 Acc: 0.9734
# val Loss: 0.0300 Acc: 1.0000
#
# Epoch 18/24
# ----------
# train Loss: 0.1429 Acc: 0.9696
# val Loss: 0.0297 Acc: 1.0000
#
# Epoch 19/24
# ----------
# train Loss: 0.1179 Acc: 0.9506
# val Loss: 0.0294 Acc: 1.0000
#
# Epoch 20/24
# ----------
# train Loss: 0.1484 Acc: 0.9544
# val Loss: 0.0293 Acc: 1.0000
#
# Epoch 21/24
# ----------
# train Loss: 0.1014 Acc: 0.9810
# val Loss: 0.0293 Acc: 1.0000
#
# Epoch 22/24
# ----------
# train Loss: 0.1204 Acc: 0.9696
# val Loss: 0.0293 Acc: 1.0000
#
# Epoch 23/24
# ----------
# train Loss: 0.1337 Acc: 0.9544
# val Loss: 0.0293 Acc: 1.0000
#
# Epoch 24/24
# ----------
# train Loss: 0.1373 Acc: 0.9582
# val Loss: 0.0292 Acc: 1.0000
#
# Training complete in 1m 40s
# Best val Acc: 1.000000
# Accuracy: 0.9500
# Precision: 0.9459
# Recall: 0.9466
# F1: 0.9461
# Confusion Matrix:
# tensor([[22,  2,  0],
#         [ 2, 36,  1],
#         [ 0,  0, 37]])
# Average accuracy: 0.9480
# Average precision: 0.9483
# Average recall: 0.9462
# Average F1 score: 0.9463
# Average Time elapsed: 98.2154 seconds
# Memory Usage: 144.9242 MiB
